# %% [markdown]
# #  PCA

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

from IPython.display import clear_output

import pandas as pd
import numpy as np
classes = {0:'T-shirt/top',
           1:'Trouser', 
           2: 'Pullover', 
           3: 'Dress', 
           4: 'Coat',
           5: 'Sandal',
           6: 'Shirt',
           7: 'Sneaker',
           8: 'Bag', 
           9: 'Ankle Boot'}
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
selected_labels = [0, 1, 5, 8, 9]

data = pd.read_csv('fashion-mnist_train.csv')
data = data.loc[data['label'].isin(selected_labels)].reset_index(drop=True)

labels = data.pop('label')
index = 0
data = data.values
images = np.reshape(data, (-1, 28, 28))

# %%
import matplotlib.pyplot as plt
plt.imshow(images[index].squeeze(), cmap = 'gray')
plt.title(classes[labels[index]])
plt.axis('off')
plt.show()
index += 1
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mean_ = data.mean(axis =0)
std_ = data.std(axis=0)

X_scaled = (data-mean_)/std_

# %%
print(f'Shape of X_scaled: {X_scaled.shape}')
features = X_scaled.T
print(f'Shape of features: {features.shape}')
cov_matrix = np.cov(features)
print(f'Shape of cov_matrix: {cov_matrix.shape}')
print('\nSneak Peak of the covariance matrix:\n')
cov_matrix[0:5, 0:5]
# Out:
# Shape of X_scaled: (30000, 784)
# Shape of features: (784, 30000)
# Shape of cov_matrix: (784, 784)
#
# Sneak Peak of the covariance matrix:
# array([[1.00003333, 0.10344873, 0.02532451, 0.02635544, 0.0259777 ],
#        [0.10344873, 1.00003333, 0.67948885, 0.16289888, 0.05367159],
#        [0.02532451, 0.67948885, 1.00003333, 0.29368204, 0.0353962 ],
#        [0.02635544, 0.16289888, 0.29368204, 1.00003333, 0.55370309],
#        [0.0259777 , 0.05367159, 0.0353962 , 0.55370309, 1.00003333]])

# %%
eig_values, eig_vectors = np.linalg.eig(cov_matrix)



print(f'First 10 eigenvalues: {eig_values[:10]}')
print(f'\n\nLast 10 eigenvalues: {eig_values[-10:]}')
# Out:
# First 10 eigenvalues: [153.06599858 134.58513832  53.62624634  45.83523074  35.94793614
#   27.1722212   16.16894956  11.26325146   9.89960743   8.76881916]
#
#
# Last 10 eigenvalues: [0.0299665  0.03232823 0.02958344 0.03207515 0.03218829 0.03185936
#  0.03047201 0.02955674 0.03128741 0.03836895]

# %%
plt.figure(figsize=(5,3))
plt.stem(eig_values[:200], use_line_collection = True)
plt.xlabel('Eigen value index')
plt.ylabel('Eigen value')
plt.show()
# Out:
# <div id='3caf16ab-720e-46ad-9be0-88b630a3db3e'></div>
# C:\Users\hp\AppData\Local\Temp\ipykernel_16576\2538849645.py:2: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(eig_values[:200], use_line_collection = True)

# %%
for i in range(200):
    exp_var = np.sum(eig_values[:i+1])*100 / np.sum(eig_values)
    print(f'Eigenvectors upto {i+1} expresses {exp_var} % variance')
# Out:
# Eigenvectors upto 1 expresses 19.523073518199535 % variance
# Eigenvectors upto 2 expresses 36.68897302741589 % variance
# Eigenvectors upto 3 expresses 43.52882746554156 % variance
# Eigenvectors upto 4 expresses 49.37496303896841 % variance
# Eigenvectors upto 5 expresses 53.96000613539761 % variance
# Eigenvectors upto 6 expresses 57.425735147930126 % variance
# Eigenvectors upto 7 expresses 59.488032417703955 % variance
# Eigenvectors upto 8 expresses 60.924623746428374 % variance
# Eigenvectors upto 9 expresses 62.187286686003894 % variance
# Eigenvectors upto 10 expresses 63.305721235345864 % variance
# Eigenvectors upto 11 expresses 64.34015921745105 % variance
# Eigenvectors upto 12 expresses 65.303453770063 % variance
# Eigenvectors upto 13 expresses 66.2215767242117 % variance
# Eigenvectors upto 14 expresses 66.99535115019921 % variance
# Eigenvectors upto 15 expresses 67.74056613252276 % variance
# Eigenvectors upto 16 expresses 68.4381673582634 % variance
# Eigenvectors upto 17 expresses 69.06144815928647 % variance
# Eigenvectors upto 18 expresses 69.65721522913019 % variance
# Eigenvectors upto 19 expresses 70.23263378314856 % variance
# Eigenvectors upto 20 expresses 70.77409539692974 % variance
# Eigenvectors upto 21 expresses 71.28998391299858 % variance
# Eigenvectors upto 22 expresses 71.77867360249294 % variance
# Eigenvectors upto 23 expresses 72.25301371878182 % variance
# Eigenvectors upto 24 expresses 72.70715322014473 % variance
# Eigenvectors upto 25 expresses 73.15049893439334 % variance
# Eigenvectors upto 26 expresses 73.57926346066206 % variance
# Eigenvectors upto 27 expresses 73.99083874980505 % variance
# Eigenvectors upto 28 expresses 74.36499478480832 % variance
# Eigenvectors upto 29 expresses 74.73228664199712 % variance
# Eigenvectors upto 30 expresses 75.09208305657287 % variance
# Eigenvectors upto 31 expresses 75.4357953296947 % variance
# Eigenvectors upto 32 expresses 75.76003634117217 % variance
# Eigenvectors upto 33 expresses 76.07692505971897 % variance
# Eigenvectors upto 34 expresses 76.39010008190414 % variance
# Eigenvectors upto 35 expresses 76.69951785965624 % variance
# Eigenvectors upto 36 expresses 76.9997349037411 % variance
# Eigenvectors upto 37 expresses 77.29743741102462 % variance
# Eigenvectors upto 38 expresses 77.5774635328411 % variance
# Eigenvectors upto 39 expresses 77.85557690851208 % variance
# Eigenvectors upto 40 expresses 78.11847151577814 % variance
# Eigenvectors upto 41 expresses 78.37460096541027 % variance
# Eigenvectors upto 42 expresses 78.62937568007645 % variance
# Eigenvectors upto 43 expresses 78.87777483330176 % variance
# Eigenvectors upto 44 expresses 79.11572208615507 % variance
# Eigenvectors upto 45 expresses 79.34999900941531 % variance
# Eigenvectors upto 46 expresses 79.57892203584007 % variance
# Eigenvectors upto 47 expresses 79.8051974844857 % variance
# Eigenvectors upto 48 expresses 80.02688232660732 % variance
# Eigenvectors upto 49 expresses 80.2417059153431 % variance
# Eigenvectors upto 50 expresses 80.45463843255448 % variance
# Eigenvectors upto 51 expresses 80.6610856111113 % variance
# Eigenvectors upto 52 expresses 80.86249284501673 % variance
# Eigenvectors upto 53 expresses 81.06125443584014 % variance
# Eigenvectors upto 54 expresses 81.25156510409522 % variance
# Eigenvectors upto 55 expresses 81.43949969033734 % variance
# Eigenvectors upto 56 expresses 81.62303601884608 % variance
# Eigenvectors upto 57 expresses 81.80346627261571 % variance
# Eigenvectors upto 58 expresses 81.98259551293377 % variance
# Eigenvectors upto 59 expresses 82.15807146471793 % variance
# Eigenvectors upto 60 expresses 82.3297085643332 % variance
# Eigenvectors upto 61 expresses 82.49512738608587 % variance
# Eigenvectors upto 62 expresses 82.65898721427412 % variance
# Eigenvectors upto 63 expresses 82.81889049024568 % variance
# Eigenvectors upto 64 expresses 82.98033615482285 % variance
# Eigenvectors upto 65 expresses 83.13693566676622 % variance
# Eigenvectors upto 66 expresses 83.29189512616547 % variance
# Eigenvectors upto 67 expresses 83.44392797509397 % variance
# Eigenvectors upto 68 expresses 83.59467704525082 % variance
# Eigenvectors upto 69 expresses 83.74185037281362 % variance
# Eigenvectors upto 70 expresses 83.88871842769694 % variance
# Eigenvectors upto 71 expresses 84.03185385046424 % variance
# Eigenvectors upto 72 expresses 84.17265034243759 % variance
# Eigenvectors upto 73 expresses 84.31171401339921 % variance
# Eigenvectors upto 74 expresses 84.44748817536444 % variance
# Eigenvectors upto 75 expresses 84.58199195122029 % variance
# Eigenvectors upto 76 expresses 84.7163002580331 % variance
# Eigenvectors upto 77 expresses 84.84685575346774 % variance
# Eigenvectors upto 78 expresses 84.97628021705384 % variance
# Eigenvectors upto 79 expresses 85.10461069554138 % variance
# Eigenvectors upto 80 expresses 85.23038207999025 % variance
# Eigenvectors upto 81 expresses 85.35423941474225 % variance
# Eigenvectors upto 82 expresses 85.47734596146171 % variance
# Eigenvectors upto 83 expresses 85.597867694012 % variance
# Eigenvectors upto 84 expresses 85.7176126734849 % variance
# Eigenvectors upto 85 expresses 85.83427598795195 % variance
# Eigenvectors upto 86 expresses 85.94667144011596 % variance
# Eigenvectors upto 87 expresses 86.0580472906712 % variance
# Eigenvectors upto 88 expresses 86.16806024394398 % variance
# Eigenvectors upto 89 expresses 86.27677116763567 % variance
# Eigenvectors upto 90 expresses 86.38486080653023 % variance
# Eigenvectors upto 91 expresses 86.49115166923652 % variance
# Eigenvectors upto 92 expresses 86.59561189419865 % variance
# Eigenvectors upto 93 expresses 86.6984936474124 % variance
# Eigenvectors upto 94 expresses 86.80027090816805 % variance
# Eigenvectors upto 95 expresses 86.90161296985823 % variance
# Eigenvectors upto 96 expresses 87.00113630636672 % variance
# Eigenvectors upto 97 expresses 87.09951895063666 % variance
# Eigenvectors upto 98 expresses 87.19660211966995 % variance
# Eigenvectors upto 99 expresses 87.29277359021046 % variance
# Eigenvectors upto 100 expresses 87.38881789642268 % variance
# Eigenvectors upto 101 expresses 87.48236516319255 % variance
# Eigenvectors upto 102 expresses 87.57533020551651 % variance
# Eigenvectors upto 103 expresses 87.66759757589003 % variance
# Eigenvectors upto 104 expresses 87.75766803159482 % variance
# Eigenvectors upto 105 expresses 87.84708182521854 % variance
# Eigenvectors upto 106 expresses 87.93534162703314 % variance
# Eigenvectors upto 107 expresses 88.02282412880491 % variance
# Eigenvectors upto 108 expresses 88.10922369152388 % variance
# Eigenvectors upto 109 expresses 88.19461142518115 % variance
# Eigenvectors upto 110 expresses 88.27926424865001 % variance
# Eigenvectors upto 111 expresses 88.36321903538746 % variance
# Eigenvectors upto 112 expresses 88.4463377713692 % variance
# Eigenvectors upto 113 expresses 88.52904273581865 % variance
# Eigenvectors upto 114 expresses 88.61070291301976 % variance
# Eigenvectors upto 115 expresses 88.69122975732913 % variance
# Eigenvectors upto 116 expresses 88.77094119102682 % variance
# Eigenvectors upto 117 expresses 88.84876593579175 % variance
# Eigenvectors upto 118 expresses 88.92532319841632 % variance
# Eigenvectors upto 119 expresses 89.00149325593577 % variance
# Eigenvectors upto 120 expresses 89.07600350317712 % variance
# Eigenvectors upto 121 expresses 89.15019232784974 % variance
# Eigenvectors upto 122 expresses 89.22300947532429 % variance
# Eigenvectors upto 123 expresses 89.29436901348294 % variance
# Eigenvectors upto 124 expresses 89.36543236585456 % variance
# Eigenvectors upto 125 expresses 89.43606707849128 % variance
# Eigenvectors upto 126 expresses 89.5061289651259 % variance
# Eigenvectors upto 127 expresses 89.57571706854154 % variance
# Eigenvectors upto 128 expresses 89.64359277907477 % variance
# Eigenvectors upto 129 expresses 89.71248561995408 % variance
# Eigenvectors upto 130 expresses 89.78012422512877 % variance
# Eigenvectors upto 131 expresses 89.84705899762471 % variance
# Eigenvectors upto 132 expresses 89.91162089756605 % variance
# Eigenvectors upto 133 expresses 89.97664310318835 % variance
# Eigenvectors upto 134 expresses 90.04270207418143 % variance
# Eigenvectors upto 135 expresses 90.1091894448518 % variance
# Eigenvectors upto 136 expresses 90.17494416119078 % variance
# Eigenvectors upto 137 expresses 90.23875262895226 % variance
# Eigenvectors upto 138 expresses 90.30197028883764 % variance
# Eigenvectors upto 139 expresses 90.36433258315289 % variance
# Eigenvectors upto 140 expresses 90.42606758546118 % variance
# Eigenvectors upto 141 expresses 90.48727349239373 % variance
# Eigenvectors upto 142 expresses 90.54811523499869 % variance
# Eigenvectors upto 143 expresses 90.60839092443288 % variance
# Eigenvectors upto 144 expresses 90.66839632988372 % variance
# Eigenvectors upto 145 expresses 90.72748710688239 % variance
# Eigenvectors upto 146 expresses 90.78665420058168 % variance
# Eigenvectors upto 147 expresses 90.84534832889933 % variance
# Eigenvectors upto 148 expresses 90.90277177461031 % variance
# Eigenvectors upto 149 expresses 90.95987544310049 % variance
# Eigenvectors upto 150 expresses 91.01657450205359 % variance
# Eigenvectors upto 151 expresses 91.07264976943071 % variance
# Eigenvectors upto 152 expresses 91.12819077894746 % variance
# Eigenvectors upto 153 expresses 91.18385287310812 % variance
# Eigenvectors upto 154 expresses 91.23897361954053 % variance
# Eigenvectors upto 155 expresses 91.29344756876226 % variance
# Eigenvectors upto 156 expresses 91.34755175936381 % variance
# Eigenvectors upto 157 expresses 91.4012112193942 % variance
# Eigenvectors upto 158 expresses 91.45426306300877 % variance
# Eigenvectors upto 159 expresses 91.50670923095086 % variance
# Eigenvectors upto 160 expresses 91.55859360579743 % variance
# Eigenvectors upto 161 expresses 91.61016101616127 % variance
# Eigenvectors upto 162 expresses 91.66088512142169 % variance
# Eigenvectors upto 163 expresses 91.71117756770842 % variance
# Eigenvectors upto 164 expresses 91.76120618222136 % variance
# Eigenvectors upto 165 expresses 91.81103703193628 % variance
# Eigenvectors upto 166 expresses 91.86034558114098 % variance
# Eigenvectors upto 167 expresses 91.90927071424557 % variance
# Eigenvectors upto 168 expresses 91.95793128301712 % variance
# Eigenvectors upto 169 expresses 92.00612988140726 % variance
# Eigenvectors upto 170 expresses 92.05402852364746 % variance
# Eigenvectors upto 171 expresses 92.10178839213448 % variance
# Eigenvectors upto 172 expresses 92.14909484733059 % variance
# Eigenvectors upto 173 expresses 92.19621186223424 % variance
# Eigenvectors upto 174 expresses 92.243007733026 % variance
# Eigenvectors upto 175 expresses 92.28941226212899 % variance
# Eigenvectors upto 176 expresses 92.3355958738343 % variance
# Eigenvectors upto 177 expresses 92.38141930664119 % variance
# Eigenvectors upto 178 expresses 92.42525812929063 % variance
# Eigenvectors upto 179 expresses 92.4696272309099 % variance
# Eigenvectors upto 180 expresses 92.5143252258695 % variance
# Eigenvectors upto 181 expresses 92.55941367710469 % variance
# Eigenvectors upto 182 expresses 92.60462502416291 % variance
# Eigenvectors upto 183 expresses 92.64821808518961 % variance
# Eigenvectors upto 184 expresses 92.6912841810563 % variance
# Eigenvectors upto 185 expresses 92.73380308892405 % variance
# Eigenvectors upto 186 expresses 92.77591722057856 % variance
# Eigenvectors upto 187 expresses 92.81790880206296 % variance
# Eigenvectors upto 188 expresses 92.85960430842415 % variance
# Eigenvectors upto 189 expresses 92.9002009273065 % variance
# Eigenvectors upto 190 expresses 92.94117427495907 % variance
# Eigenvectors upto 191 expresses 92.98250947471587 % variance
# Eigenvectors upto 192 expresses 93.02368940424195 % variance
# Eigenvectors upto 193 expresses 93.06387924339074 % variance
# Eigenvectors upto 194 expresses 93.10372885357259 % variance
# Eigenvectors upto 195 expresses 93.14317082722657 % variance
# Eigenvectors upto 196 expresses 93.1828550664471 % variance
# Eigenvectors upto 197 expresses 93.22186910944352 % variance
# Eigenvectors upto 198 expresses 93.26078276733305 % variance
# Eigenvectors upto 199 expresses 93.29586863252958 % variance
# Eigenvectors upto 200 expresses 93.3345065246247 % variance

# %%
X_scaled[0].reshape((-1, 784)).shape
# Out:
# (1, 784)

# %%
eig_vectors[:, 0].reshape((784, -1)).shape
# Out:
# (784, 1)

# %%
result = np.dot(X_scaled.reshape((-1, 784)), eig_vectors[:,:50].reshape((784, -1)))
result.shape
# Out:
# (30000, 50)

# %%
projected_1 = X_scaled.dot(eig_vectors.T[0])
projected_2 = X_scaled.dot(eig_vectors.T[1])
res2d = pd.DataFrame(projected_1, columns=['PC1'])
res2d['PC2'] = projected_2
res2d['Y'] = labels
res2d.head()
# Out:
#          PC1        PC2  Y
# 0 -13.846035  -3.141500  9
# 1  13.780054   8.119654  0
# 2  -4.080987 -20.163169  5
# 3   4.344533   0.808241  8
# 4  21.412902  19.844596  0

# %%
plt.figure(figsize=(6,4))
for label in selected_labels:
    label_name = classes[label]
    coords = res2d[res2d['Y']==label]
    x = coords['PC1'].values
    y = coords['PC2'].values
    plt.scatter(x, y, label=label_name)

plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
projected_1 = X_scaled.dot(eig_vectors.T[0])
projected_2 = X_scaled.dot(eig_vectors.T[1])
projected_3 = X_scaled.dot(eig_vectors.T[2])
res3d = pd.DataFrame(projected_1, columns=['PC1'])
res3d['PC2'] = projected_2
res3d['PC3'] = projected_3
res3d['Y'] = labels
res3d = res3d.head(500)

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(projection='3d')

for label in selected_labels:
    label_name = classes[label]
    coords = res3d[res3d['Y']==label]
    x = coords['PC1'].values
    y = coords['PC2'].values
    z = coords['PC3'].values
    ax.scatter3D(x, y, z, label=label_name)
    
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
reduced_eigen_space = eig_vectors[:, :350]

# %%
print(f'Shape of X_scaled: {X_scaled.shape}')
print(f'Shape of reduced_eigen_space: {reduced_eigen_space.shape}')
X_compressed = np.dot(X_scaled, reduced_eigen_space)
print(f'Shape of X_compressed: {X_compressed.shape}')
# Out:
# Shape of X_scaled: (30000, 784)
# Shape of reduced_eigen_space: (784, 350)
# Shape of X_compressed: (30000, 350)

# %%
print(f'Shape of X_compressed: {X_compressed.shape}')
print(f'Shape of reduced_eigen_space: {reduced_eigen_space.shape}')
X_reconstructed = np.dot(X_compressed,reduced_eigen_space.T)
print(f'Shape of X_reconstructed: {X_reconstructed.shape}')
# Out:
# Shape of X_compressed: (30000, 350)
# Shape of reduced_eigen_space: (784, 350)
# Shape of X_reconstructed: (30000, 784)

# %%
rec_index = 0

# %%
data_reconstructed = (X_reconstructed * std_ ) + mean_
reconstructed_images = np.reshape(data_reconstructed, (-1, 28, 28))

# %%
f = plt.figure()
ax1 = f.add_subplot(1,2,1)
plt.imshow(images[rec_index].squeeze(), cmap = 'gray')
ax1.axis(False)
ax2 = f.add_subplot(1,2,2)
ax2.axis(False)
plt.imshow(reconstructed_images[rec_index].squeeze(), cmap = 'gray')
ax1.title.set_text('Original')
ax2.title.set_text('Reconstructed after Compression')
plt.show(block=True)
rec_index +=1
# Out:
# <img src="data:image/png;base64,..." width="640">
